# %%
import spartaquant as sq
sq = sq.spartaquant()

# %%
sq.getDataDB()

# %%
ticker = 'MSFT'

# %%
sq.runFunction('Getyahoo', ticker, '2014-01-01')

# %%
sq.runFunction('GetYahooFinancials_MTQtMDItMjAyMiAxMzo0OToxOA', ticker,  'annual',  'income')
